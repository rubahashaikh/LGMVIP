# %% [markdown]
# # LETS GROW MORE (LGM)

# %% [markdown]
# # TASK 2 (INTERMEDIATE LEVEL TASK)

# %% [markdown]
# # (1) ---- Exploratory Data Analysis on Terrorism Dataset

# %% [markdown]
# # NAME: RUBAHA SHAIKH

# %% [markdown]
# # Dataset: https://bit.ly/2TK5Xn5

# %% [markdown]
# # Importing all libraries

# %%
import pandas as pd
import numpy as np

terr_data = pd.read_csv("globalterrorismdb_0718dist.csv",encoding = "ISO-8859-1", low_memory=False)

# %%
terr_data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terr_data.shape
# Out:
# (181691, 135)

# %%
terr_data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# # rename specific column names

# %%
terr_data.rename(columns = {'iyear':'year', 'imonth':'month','iday':'day','country_txt':'country_place','scite1':'attack','scite2':'attack1','scite3':'attack2'}, inplace = True)
terr_data.head(1)
# Out:
#         eventid  year  month  day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
#
#         country_place  region  ... addnotes attack attack1  attack2  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN     NaN      NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
#
# [1 rows x 135 columns]

# %%
print("Unique values in eventid is {} and in country is {}".format(terr_data["eventid"].nunique(),terr_data["country"].nunique()))
# Out:
# Unique values in eventid is 181691 and in country is 205

# %% [markdown]
# # Filling Nan values in data

# %%
terr_data['approxdate'] = terr_data['approxdate'].fillna(0)

# %%
terr_data['resolution'] = terr_data['resolution'].fillna("--")

# %%
terr_data['addnotes'] = terr_data['addnotes'].fillna("no data")
terr_data.head()
# Out:
#         eventid  year  month  day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2          0         0         --       58
# 1  197000000002  1970      0    0          0         0         --      130
# 2  197001000001  1970      1    0          0         0         --      160
# 3  197001000002  1970      1    0          0         0         --       78
# 4  197001000003  1970      1    0          0         0         --      101
#
#         country_place  region  ... addnotes attack attack1  attack2  dbsource  \
# 0  Dominican Republic       2  ...  no data    NaN     NaN      NaN      PGIS
# 1              Mexico       1  ...  no data    NaN     NaN      NaN      PGIS
# 2         Philippines       5  ...  no data    NaN     NaN      NaN      PGIS
# 3              Greece       8  ...  no data    NaN     NaN      NaN      PGIS
# 4               Japan       4  ...  no data    NaN     NaN      NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terr_data['attack'] = terr_data['attack'].fillna("null")

# %%
terr_data['attack1'] = terr_data['attack1'].fillna("other")

# %%
terr_data['attack2'] = terr_data['attack2'].fillna("other")

# %%
terr_data.head()
# Out:
#         eventid  year  month  day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2          0         0         --       58
# 1  197000000002  1970      0    0          0         0         --      130
# 2  197001000001  1970      1    0          0         0         --      160
# 3  197001000002  1970      1    0          0         0         --       78
# 4  197001000003  1970      1    0          0         0         --      101
#
#         country_place  region  ... addnotes attack attack1  attack2  dbsource  \
# 0  Dominican Republic       2  ...  no data   null   other    other      PGIS
# 1              Mexico       1  ...  no data   null   other    other      PGIS
# 2         Philippines       5  ...  no data   null   other    other      PGIS
# 3              Greece       8  ...  no data   null   other    other      PGIS
# 4               Japan       4  ...  no data   null   other    other      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
terr_data.isnull().sum()
# Out:
# eventid            0
# year               0
# month              0
# day                0
# approxdate         0
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#as it showing related column is full of null values so filling it with some random data

terr_data['related'] = terr_data['related'].fillna("2")

# %%
terr_data.head(4)
# Out:
#         eventid  year  month  day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2          0         0         --       58
# 1  197000000002  1970      0    0          0         0         --      130
# 2  197001000001  1970      1    0          0         0         --      160
# 3  197001000002  1970      1    0          0         0         --       78
#
#         country_place  region  ... addnotes attack attack1  attack2  dbsource  \
# 0  Dominican Republic       2  ...  no data   null   other    other      PGIS
# 1              Mexico       1  ...  no data   null   other    other      PGIS
# 2         Philippines       5  ...  no data   null   other    other      PGIS
# 3              Greece       8  ...  no data   null   other    other      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0        2
# 1        0         1        1       1        2
# 2       -9        -9        1       1        2
# 3       -9        -9        1       1        2
#
# [4 rows x 135 columns]

# %%
terr_data['country_place'].unique()
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
#        'Yugoslavia', 'Ecuador', 'New Zealand', 'Malaysia', 'Singapore',
#        'Botswana', 'Jamaica', 'Chad', 'North Yemen', 'Andorra', 'Syria',
#        'South Korea', 'United Arab Emirates', 'South Africa', 'Kenya',
#        'Iraq', 'Somalia', 'Tanzania', 'Sri Lanka', 'Namibia', 'Bahamas',
#        'Nigeria', 'Barbados', 'Trinidad and Tobago', 'Bangladesh',
#        'Angola', 'Mauritania', 'Saudi Arabia', 'Djibouti', 'Indonesia',
#        'Malta', 'Rhodesia', 'Soviet Union', 'Denmark', 'Western Sahara',
#        'Guyana', 'Mozambique', 'Tunisia', 'Uganda', 'Norway', 'Lesotho',
#        'Gabon', 'Libya', 'Bahrain', 'Hong Kong', 'Senegal', 'Zimbabwe',
#        'Guinea', 'Grenada', 'New Hebrides', 'Belize', 'Guadeloupe',
#        'Martinique', 'Vatican City', 'Albania',
#        'Central African Republic', 'Seychelles', 'Dominica', 'Qatar',
#        'Bulgaria', 'Suriname', 'Swaziland', 'Luxembourg', 'Iceland',
#        'French Guiana', 'Falkland Islands', 'Burkina Faso',
#        'New Caledonia', 'Romania', 'Niger', 'Nepal', 'Togo', 'Finland',
#        'Fiji', 'Ghana', 'Maldives', 'Mauritius', 'Hungary', 'Laos',
#        'Papua New Guinea', 'China', 'Liberia', 'Republic of the Congo',
#        'Mali', 'Germany', 'Yemen', 'Rwanda', 'Sierra Leone', 'Cameroon',
#        'Cuba', 'Croatia', 'Georgia', 'Azerbaijan', 'Madagascar',
#        'Lithuania', 'Burundi', 'Ukraine', 'Moldova', 'Armenia', 'Russia',
#        'Ivory Coast', 'Kazakhstan', 'Antigua and Barbuda',
#        'Bosnia-Herzegovina', 'Equatorial Guinea', 'Tajikistan', 'Malawi',
#        'Uzbekistan', 'Latvia', 'Estonia', 'Vietnam', 'Comoros', 'Benin',
#        'Slovak Republic', 'Macedonia', 'Wallis and Futuna', 'Belarus',
#        'Czech Republic', 'Slovenia', 'Gambia', 'North Korea', 'Eritrea',
#        'St. Kitts and Nevis', 'French Polynesia', 'Macau', 'Kyrgyzstan',
#        'Vanuatu', 'Democratic Republic of the Congo', 'Kosovo',
#        'Solomon Islands', 'East Timor', 'St. Lucia', 'Guinea-Bissau',
#        'Montenegro', 'International', 'Turkmenistan', 'Serbia-Montenegro',
#        'Bhutan', 'Serbia', 'South Sudan'], dtype=object)

# %%
terr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
terr_data.describe()
# Out:
#             eventid           year          month            day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# # Checking mean values in specific column by using group_by function

# %%
terr_data.groupby(['country_place']).mean().head(4)
# Out:
#                     eventid         year     month        day  extended  \
# country_place
# Afghanistan    2.012887e+11  2012.819260  6.604509  15.774723  0.072657
# Albania        1.999129e+11  1999.062500  6.512500  17.037500  0.000000
# Algeria        2.000576e+11  2000.509296  6.478308  15.200146  0.032446
# Andorra        1.974071e+11  1974.000000  7.000000  14.000000  0.000000
#
#                country  region   latitude  longitude  specificity  ...  \
# country_place                                                      ...
# Afghanistan        4.0     6.0  33.878726  67.191111     2.086724  ...
# Albania            5.0     9.0  41.077462  19.838797     1.150000  ...
# Algeria            6.0    10.0  36.223004   3.397750     1.372949  ...
# Andorra            7.0     8.0        NaN        NaN     5.000000  ...
#
#                   ransomamt   ransomamtus     ransompaid  ransompaidus  \
# country_place
# Afghanistan    2.702768e+06  6.111111e+03    2569.738000    555.555556
# Albania                 NaN           NaN            NaN           NaN
# Algeria        1.778367e+06  2.133327e+06  250921.583333    -14.142857
# Andorra                 NaN           NaN            NaN           NaN
#
#                hostkidoutcome  nreleased   INT_LOG  INT_IDEO  INT_MISC  \
# country_place
# Afghanistan          4.985689 -32.829535 -3.427618 -3.325348  0.142801
# Albania                   NaN        NaN -9.000000 -9.000000 -0.112500
# Algeria              5.113475 -35.610169 -5.107546 -5.102807 -0.026613
# Andorra                   NaN        NaN  0.000000  1.000000  1.000000
#
#                 INT_ANY
# country_place
# Afghanistan   -2.565549
# Albania       -7.875000
# Algeria       -4.858549
# Andorra        1.000000
#
# [4 rows x 77 columns]

# %%
terr_data.groupby(['weaptype1_txt']).mean().head(4)
# Out:
#                     eventid         year     month        day  extended  \
# weaptype1_txt
# Biological     1.999230e+11  1999.142857  8.571429  14.742857  0.057143
# Chemical       2.002900e+11  2002.838006  6.080997  13.803738  0.003115
# Explosives     2.004200e+11  2004.133436  6.463030  15.594519  0.003679
# Fake Weapons   1.997174e+11  1997.121212  5.090909  14.333333  0.060606
#
#                   country    region   latitude  longitude  specificity  ...  \
# weaptype1_txt                                                           ...
# Biological     210.685714  3.028571  33.319696 -49.524213     1.228571  ...
# Chemical       117.239875  6.894081  27.500675  36.294964     1.610592  ...
# Explosives     126.542315  7.456971  25.226616  30.915416     1.366420  ...
# Fake Weapons   128.878788  6.363636  29.919133  15.871436     1.242424  ...
#
#                   ransomamt  ransomamtus    ransompaid  ransompaidus  \
# weaptype1_txt
# Biological              NaN          NaN           NaN           NaN
# Chemical                NaN          NaN           NaN           NaN
# Explosives     1.103738e+07   -14.142857  63861.663636    -14.142857
# Fake Weapons   6.410656e+05     0.000000    388.800000      0.000000
#
#                hostkidoutcome  nreleased   INT_LOG  INT_IDEO  INT_MISC  \
# weaptype1_txt
# Biological                NaN        NaN -6.628571 -6.542857  0.057143
# Chemical             4.666667 -15.666667 -4.925234 -4.816199  0.109034
# Explosives           4.658257 -18.050602 -5.002975 -4.914310  0.090137
# Fake Weapons         3.545455  77.666667 -5.878788 -5.818182  0.060606
#
#                 INT_ANY
# weaptype1_txt
# Biological    -6.485714
# Chemical      -3.925234
# Explosives    -4.427120
# Fake Weapons  -3.666667
#
# [4 rows x 77 columns]

# %% [markdown]
# # DATA VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# New Code 01

y_count = pd.DataFrame(terr_data['year'].value_counts(dropna = False).sort_index()).reset_index()
y_count.rename(columns = {'index':'yearY', 'year':'count'}, inplace = True)
sns.lineplot(x= 'yearY', y= 'count', data=y_count)
# Out:
# <AxesSubplot:xlabel='yearY', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y = terr_data['year'].unique()
y_count = terr_data['year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = y, y = y_count, palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('year',fontsize=22)
plt.ylabel('Number of Attacks in Each Year',fontsize=22)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
new_Attack_DF = pd.DataFrame(terr_data['country'].groupby(terr_data['weaptype1_txt']).count()).reset_index()
atk_data_plot = new_Attack_DF.sort_values('country',ascending=False).head(5).reset_index()

# Randomly reorder the data to make it qualitative
sns.set(rc={'figure.figsize':(15,7)})
sns.barplot(x='weaptype1_txt', y='country', data=atk_data_plot)
# plt.figure(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='weaptype1_txt', ylabel='country'>

# %%
labels = atk_data_plot['weaptype1_txt']
x = atk_data_plot['country']
explode = [0, 0, 0, 0, 0]
colors = sns.color_palette('pastel')
# plt.pie(x, labels = labels, colors = colors)
# plt.show()
plt.pie(x, labels=labels, colors=colors, explode=explode, autopct='%.0f%%')
plt.show()

# %% [markdown]
# # THANKYOU
